# %%
import pandas as pd
import os

print("Pandas version:", pd.__version__)
print("Setup working!")
# Out:
# Pandas version: 2.3.3
# Setup working!

# %%
# The project doc tells us core files use header=1 (row 0 is metadata, row 1 has column names)
companies = pd.read_excel('data/raw/companies.xlsx', header=1)

print("Shape:", companies.shape)          # (rows, columns)
print("\nColumn names:\n", companies.columns.tolist())
print("\nFirst 3 rows:")
companies.head(3)
# Out:
# Shape: (92, 12)
#
# Column names:
#  ['id', 'company_logo', 'company_name', 'chart_link', 'about_company', 'website', 'nse_profile', 'bse_profile', 'face_value', 'book_value', 'roce_percentage', 'roe_percentage']
#
# First 3 rows:
#            id                                       company_logo  \
# 0         ABB   https://mkt.in/static/mkt-icons/nifty100/ABB.png
# 1  ADANIENSOL  https://m.economictimes.com/thumb/msid-1173715...
# 2    ADANIENT  https://mkt.in/static/mkt-icons/nifty100/ADANI...
#
#                  company_name  \
# 0            Abbott India Ltd
# 1  Adani Energy Solutions Ltd
# 2       Adani Enterprises Ltd
#
#                                           chart_link  \
# 0  https://in.tradingview.com/chart/?symbol=NSE%3...
# 1  https://in.tradingview.com/chart/?symbol=NSE%3...
# 2  https://in.tradingview.com/chart/?symbol=ADANIENT
#
#                                        about_company  \
# 0  Abbott India Ltd is one of the leading multina...
# ...

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\VISHNU\Downloads\nifty100_project\.venv\Scripts\python.exe

# %%
print("Missing values per column:")
print(companies.isnull().sum())
# Out:
# Missing values per column:
# id                 0
# company_logo       1
# company_name       0
# chart_link         0
# about_company      0
# website            1
# nse_profile        1
# bse_profile        1
# face_value         1
# book_value         1
# roce_percentage    1
# roe_percentage     2
# dtype: int64

# %%
pl = pd.read_excel('data/raw/profitandloss.xlsx', header=1)

print("Shape:", pl.shape)
print("\nColumn names:", pl.columns.tolist())
print("\nUnique companies:", pl['company_id'].nunique())
print("\nYear range sample:", pl['year'].unique()[:10])
print("\nSample rows:")
pl.head(5)
# Out:
# Shape: (1276, 15)
#
# Column names: ['id', 'company_id', 'year', 'sales', 'expenses', 'operating_profit', 'opm_percentage', 'other_income', 'interest', 'depreciation', 'profit_before_tax', 'tax_percentage', 'net_profit', 'eps', 'dividend_payout']
#
# Unique companies: 100
#
# Year range sample: ['Dec 2012' 'Mar 2014' 'Mar 2015' 'Mar 2016' 'Mar 2017' 'Mar 2018'
#  'Mar 2019' 'Mar 2020' 'Mar 2021' 'Mar 2022']
#
# Sample rows:
#    id company_id      year  sales  expenses  operating_profit  opm_percentage  \
# 0  61        ABB  Dec 2012   1653      1451             202.0            12.0
# 1  62        ABB  Mar 2014   2276      2009             267.0            12.0
# 2  63        ABB  Mar 2015   2289      1977             312.0            14.0
# 3  64        ABB  Mar 2016   2614      2250             365.0            14.0
# 4  65        ABB  Mar 2017   2903      2505             398.0            14.0
#
#    other_income  interest  depreciation  profit_before_tax  tax_percentage  \
# ...

# %%
core_files = {
    'companies':      'data/raw/companies.xlsx',
    'profit_and_loss':'data/raw/profitandloss.xlsx',
    'balance_sheet':  'data/raw/balancesheet.xlsx',
    'cash_flow':      'data/raw/cashflow.xlsx',
    'analysis':       'data/raw/analysis.xlsx',
    'documents':      'data/raw/documents.xlsx',
    'prosandcons':    'data/raw/prosandcons.xlsx',
}

for name, path in core_files.items():
    df = pd.read_excel(path, header=1)
    print(f"{name:20s} → {df.shape[0]:>5} rows, {df.shape[1]:>2} columns")
# Out:
# companies            →    92 rows, 12 columns
# profit_and_loss      →  1276 rows, 15 columns
# balance_sheet        →  1312 rows, 13 columns
# cash_flow            →  1187 rows,  7 columns
# analysis             →    20 rows,  6 columns
# documents            →  1585 rows,  4 columns
# prosandcons          →    16 rows,  4 columns

# %%
pl_sample = pd.read_excel('data/raw/profitandloss.xlsx', header=1)

print("Year column — first 20 unique values:")
print(pl_sample['year'].unique()[:20])
# Out:
# Year column — first 20 unique values:
# ['Dec 2012' 'Mar 2014' 'Mar 2015' 'Mar 2016' 'Mar 2017' 'Mar 2018'
#  'Mar 2019' 'Mar 2020' 'Mar 2021' 'Mar 2022' 'Mar 2023' 'Mar 2024' 'TTM'
#  'Mar 2013' 'Dec 2013' 'Dec 2014' 'Dec 2015' 'Dec 2016' 'Dec 2017'
#  'Dec 2018']
